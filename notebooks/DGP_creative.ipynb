# %% [markdown]
# The aim of this notebook is to test running a DGP which can be used to test the EconML pipeline. Generate synthetic data in the iPinYou dataset format. Firstly without any sparsisty or positivity assumption issues and then otherwise afterwards.

# %%
# imports

# %%
N_SAMPLES = 1000

N_CREATIVES = 8

CLICK_RATE = 0.3 # unrealistic but dont want to suffer from sparsity issue
# in this motivating example 

RANDOM_STATE = 124

TRUE_CREATIVE_EFFECTS = {
    "creative_0": 0.000,
    "creative_1": 0.005,
    "creative_2": 0.010,
    "creative_3": 0.015,
    "creative_4": 0.020,
    "creative_5": 0.030,
    "creative_6": 0.040,
    "creative_7": 0.060,
}

# %% [markdown]
# This may not be a feasible task as I would need to:
# - generate all 27 rows of iPinYou
# - create a realistic treatment assignment via a multinomial (softmax) model
# - create a configurable causal click model with known tratment effects
# - create synthetic identifiers
# - the complete feature engineering pipeline (not sure this is necessary)
